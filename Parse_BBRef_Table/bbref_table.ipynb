# %%
from pyball import *

#table = get_lookup_table()

# %%
#playerid_lookup("clase", "emmanuel")
#playerid_lookup("ramirez", "jose")

# %%
clase = makeSavantURL("clase", "emmanuel", "661403")
ramirez = makeSavantURL("ramirez", "jose", "608070")
#savantPitchTracking(url)

# %%
# percentile batting stats for Jose Ramirez
savantPercentileStats(ramirez)
# Out:
#    Year  xwOBA  xBA  xSLG  xISO  xOBP  Brl  Brl%  EV  Max EV  Hard Hit%  K%  \
# 0  2015     25   25    14    17    45    9    14  20      52         12  92
# 1  2016     57   94    46    25    77   27    18  38      78         30  97
# 2  2017     81   99    78    57    80   53    35  51      62         45  98
# 3  2018     87   66    79    75    95   86    59  53      75         37  95
# 4  2019     63   66    59    53    68   47    33  50      84         32  89
# 5  2020     84   67    84    86    80   87    66  48      95         32  79
# 6  2021     89   88    85    79    92   87    73  66      86         60  92
# 7  2022     63   72    60    48    82   67    35  33      95         40  98
#
#    BB%  Whiff%  Chase Rate  Speed   OAA
# 0   69      96          78     78   NaN
# 1   35      95          66     74   NaN
# 2   45      95          79     74  93.0
# 3   95      95          90     58  79.0
# 4   63      95          82     72  89.0
# ...

# %%
# percentile pitching stats for Emmanuel Clase
savantPercentileStats(clase)
# Out:
#    Year  xwOBA  / xERA   xBA  xSLG   xISO   xOBP   Brl   Brl%    EV  \
# 0  2019            NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN
# 1  2021           99.0  87.0  98.0  100.0   98.0  99.0  100.0  91.0
# 2  2022          100.0  91.0  99.0   99.0  100.0  99.0  100.0  90.0
#
#    Hard Hit%    K%   BB%  Whiff%  Chase Rate  FB Velo  FB Spin  CB Spin  \
# 0        NaN   NaN   NaN     NaN         NaN      100       97      NaN
# 1       96.0  69.0  86.0    89.0        99.0      100       98      NaN
# 2       86.0  82.0  95.0    78.0       100.0      100      100      NaN
#
#    Extension
# 0         78
# 1         61
# 2         64

# %%
# savant batting stats for Jose Ramirez
savantBattingStatcastStats(ramirez)
# Out:
#    Season   Age  Pitches  Batted Balls  Barrels  Barrel %  Barrel/PA  \
# 0    2015  22.0   1416.0         283.0      5.0       1.8        1.4
# 1    2016  23.0   2428.0         508.0     15.0       3.0        2.4
# 2    2017  24.0   2576.0         521.0     26.0       5.0        4.0
# 3    2018  25.0   3002.0         504.0     42.0       8.3        6.0
# 4    2019  26.0   2173.0         414.0     26.0       6.3        4.8
# 5    2020  27.0   1146.0         177.0     18.0      10.2        7.1
# 6    2021  28.0   2675.0         470.0     52.0      11.1        8.2
# 7    2022  29.0   2365.0         457.0     30.0       6.6        5.1
# 8  Player   NaN  17781.0        3334.0    214.0       6.4        4.9
#
#    Exit Velocity  Max EV  Launch Angle  Sweet Spot %    XBA   XSLG   WOBA  \
# 0           86.7   106.7          11.9          27.9  0.240  0.336  0.280
# 1           88.4   110.7          13.2          35.0  0.290  0.416  0.355
# ...

# %%
# savant pitching stats for Emmanuel Clase
savantPitchingStatcastStats(clase)
# Out:
#    Season   Age  Pitches  Batted Balls  Barrels  Barrel %  Barrel/PA  \
# 0    2019  21.0    345.0          66.0      3.0       4.5        3.2
# 1    2021  23.0   1057.0         189.0      3.0       1.6        1.1
# 2    2022  24.0    774.0         154.0      2.0       1.3        0.9
# 3  Player   NaN   2176.0         409.0      8.0       2.0        1.3
#
#    Exit Velocity  Max EV  Launch Angle  ...    XBA   XSLG   WOBA  XWOBA  \
# 0           86.4   107.5           3.2  ...  0.237  0.353  0.289  0.283
# 1           86.4   109.3          -0.2  ...  0.203  0.267  0.212  0.228
# 2           86.4   109.5           0.0  ...  0.193  0.254  0.183  0.212
# 3           86.4   109.5           0.4  ...  0.205  0.276  0.213  0.231
#
#    XWOBACON  HardHit%    K%  BB%   ERA  xERA
# 0     0.330      34.8  22.3  6.4  2.31  3.48
# 1     0.286      29.6  26.5  5.7  1.29  2.17
# 2     0.277      32.5  28.1  4.4  1.31  1.85
# 3     0.290      31.5  26.5  5.3   NaN   NaN
#
# [4 rows x 21 columns]

# %%
# batted ball profile for Jose Ramirez
savantBattedBallProfile(ramirez)
# Out:
#    Season  GB %  FB %  LD %  PU %  Pull %  Straight %  Oppo %  Weak %  \
# 0    2015  49.8  23.3  19.8   7.1    39.9        34.6    24.7     1.8
# 1    2016  41.5  20.1  31.7   6.7    35.6        36.2    28.1     3.0
# 2    2017  40.3  24.4  27.6   7.7    42.8        34.9    22.3     3.8
# 3    2018  33.9  31.2  23.4  11.5    47.8        33.9    18.3     1.2
# 4    2019  33.8  29.7  25.6  10.9    48.1        31.2    20.8     2.2
# 5    2020  29.9  29.4  24.9  15.8    47.5        33.9    18.6     2.3
# 6    2021  36.2  27.0  24.0  12.8    54.7        30.2    15.1     3.4
# 7    2022  32.6  28.0  25.4  14.0    45.5        35.0    19.5     4.6
# 8  Player  37.3  26.5  25.7  10.5    45.2        33.8    21.0     2.9
# 9     MLB  44.9  23.0  25.0   7.1    36.8        37.7    25.4     3.8
#
#    Topped %  Under %  Flare/Burner %  Solid %  Barrel %  Barrel/PA
# 0      36.4     29.7            23.3      2.8       1.8        1.4
# ...

# %%
# batted ball profile for Emmanuel Clase
savantBattedBallProfile(clase)
# Out:
#    Season  GB %  FB %  LD %  PU %  Pull %  Straight %  Oppo %  Weak %  \
# 0    2019  59.1  13.6  27.3   0.0    42.4        34.8    22.7     7.6
# 1    2021  68.3  12.7  16.4   2.6    37.6        37.0    25.4     4.2
# 2    2022  65.6  13.0  18.2   3.2    31.2        48.1    20.8     4.5
# 3  Player  65.8  13.0  18.8   2.4    35.9        40.8    23.2     4.9
# 4     MLB  44.9  23.0  25.0   7.1    36.8        37.7    25.4     3.8
#
#    Topped %  Under %  Flare/Burner %  Solid %  Barrel %  Barrel/PA
# 0      47.0     12.1            25.8      3.0       4.5        3.2
# 1      54.0     12.2            25.4      2.6       1.6        1.1
# 2      55.8     12.3            17.5      6.5       1.3        0.9
# 3      53.5     12.2            22.5      4.2       2.0        1.3
# 4      33.0     24.6            24.4      5.7       6.7        4.6

# %%
# pitch-by-pitch data for Jose Ramirez
savantPitchTracking(ramirez)
# Out:
#     Year Pitch Type     #     %   PA   AB    H  1B  2B  3B  ...     BA    XBA  \
# 0   2022  Fastballs  1190  50.4  295  265   75  36  22   1  ...  0.283  0.258
# 1   2022   Breaking   653  27.6  140  124   34  16  12   2  ...  0.274  0.253
# 2   2022   Offspeed   520  22.0  137  128   35  21   7   1  ...  0.273  0.273
# 3   2021  Fastballs  1377  51.6  348  306   83  37  20   3  ...  0.271  0.305
# 4   2021   Offspeed   649  24.3  137  123   33  18   9   0  ...  0.268  0.273
# 5   2021   Breaking   645  24.1  140  122   31  19   3   2  ...  0.254  0.238
# 6   2020  Fastballs   578  50.4  138  114   34  12  10   0  ...  0.298  0.278
# 7   2020   Breaking   343  29.9   65   56   15   8   5   0  ...  0.268  0.212
# 8   2020   Offspeed   225  19.6   51   49   15  10   1   1  ...  0.306  0.292
# 9   2019  Fastballs  1195  55.3  328  289   76  34  23   0  ...  0.263  0.276
# 10  2019   Breaking   564  26.1  108   95   25  14   6   2  ...  0.263  0.280
# ...

# %%
# pitch-by-pitch data for Emmanuel Clase
savantPitchTracking(clase)
# Out:
#    Year       Pitch Type    #  # RHB  # LHB     %    MPH   PA   AB   H  ...  \
# 0  2022           Cutter  465    245    220  60.1   99.6  125  118  22  ...
# 1  2022           Slider  292    193     99  37.7   92.0   95   92  10  ...
# 2  2022  4-Seam Fastball   17      4     13   2.2  100.0    6    6   3  ...
# 3  2021           Cutter  731    386    345  69.2  100.2  189  178  42  ...
# 4  2021           Slider  315    181    134  29.8   91.9   84   82   9  ...
# 5  2021  4-Seam Fastball   10      5      5   0.9  100.7    3    2   0  ...
# 6  2019           Cutter  253    121    132  73.3   99.2   76   70  17  ...
# 7  2019           Slider   73     44     29  21.2   90.5   14   13   3  ...
# 8  2019  4-Seam Fastball   19      7     12   5.5   99.5    4    4   0  ...
#
#      SLG   XSLG   WOBA  XWOBA    EV  LA  Spin  Ext.  Whiff%  PutAway%
# 0  0.229  0.279  0.205  0.242  84.9  -4  2642   6.5    22.3      28.6
# ...
